# %% [markdown]
# #### Digital Signal Processing Courseware: An Introduction (copyright © 2024)
# ## Authors: J. Christopher Edgar and Gregory A. Miller
#
# Conversion from Mathematica to Jupyter Notebook by Song Liu.
#
# The authors of this book are indebted to Prof. Bruce Carpenter (University of Illinois Urbana-Champaign). Bruce inspired the creation of this courseware, he consulted with the authors as this courseware was being developed, and he provided the original version of the code and text for several sections of this courseware (e.g. the section on complex numbers and the section on normal distributions).

# %% [markdown]
# # <font color=red>DSP.04 Convolution and Filtering - Spatial Domain</font>

# %% [markdown]
# # <font color=red>Literacy</font>

# %% [markdown]
# ## <font color=red>DSP.04.L.1) Normal Distributions</font>

# %% [markdown]
# Given a normal distribution:
#
# What percentage of cases fall between +/- 1 standard deviations: _________
#
# What percentage of cases fall between +/- 2 standard deviations:__________
#
# What percentage of cases fall between +/- 3 standard deviations:__________

# %% [markdown]
# ## <font color=red>DSP.04.L.2) </font>

# %% [markdown]
# Here is a plot of random values (normally distributed). The mean is 0 and the standard deviation is 4.

# %%
x = np.arange(0, 30000, 1)
noise = np.random.normal(0,4,30000)

plt.scatter(x, noise, c ="red", s= 1)
plt.text(32000,0,'time', fontsize=15)
plt.text(0,15,'amplitude', fontsize=15)

plt.show()

# %% [markdown]
# Given the above:
#
# What y-axis values bound datapoints falling +/1 SD from the mean:____________.
#
# What y-axis values bound datapoints falling +/2 SD from the mean:____________.
#
# What y-axis values bound datapoints falling +/3 SD from the mean:____________.

# %% [markdown]
# ## <font color=red>DSP.04.L.3) </font>

# %% [markdown]
# True or False: The greater the variance, the more tightly clustered the values.

# %% [markdown]
# ## <font color=red>DSP.04.L.4) </font>

# %% [markdown]
# True or False: The larger the mean, the greater the variance.

# %% [markdown]
# ## <font color=red>DSP.04.L.5) </font>

# %% [markdown]
# Sketch a normal distribution curve with a mean of 0 and a standard deviation of 2.

# %% [markdown]
# ## <font color=red>DSP.04.L.6) </font>

# %% [markdown]
# Here is a dataset: {3, 4, 6, 1, 2, 3, 4, 3, 4, 2, 3, 4, 2}.
#
# Calculate the mean and variance.

# %% [markdown]
# ## <font color=red>DSP.04.L.7) </font>

# %% [markdown]
# Using the information you computed for the dataset above, calculate the z-score for a value of 10. What
# does the z-score tell you?

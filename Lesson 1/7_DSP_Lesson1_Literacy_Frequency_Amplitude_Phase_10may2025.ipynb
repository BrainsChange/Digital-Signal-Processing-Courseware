# %% [markdown]
# #### Digital Signal Processing Courseware: An Introduction (copyright © 2024)
# ## Authors: J. Christopher Edgar and Gregory A. Miller
#
# Originally written in Mathematica by J. Christopher Edgar. Conversion to Jupyter Notebook by Song Liu.
#
# The authors of this courseware are indebted to Prof. Bruce Carpenter (University of Illinois Urbana-Champaign). Bruce inspired the creation of this courseware, he consulted with the authors as this courseware was being developed, and he provided the original version of the code and text for several sections of this courseware (e.g. the section on complex numbers and the section on normal distributions).

# %% [markdown]
# # <font color=red>DSP.01 Frequency, Amplitude, and Phase</font>
# # <font color=red>LITERACY</font>

# %% [markdown]
# **Congrats - you reached the final section! Print out this section and complete using a pencil. Bring your completed Literacy sheet to the workshop.**

# %% [markdown]
# ## <font color=red>L.1) Stationary timeseries</font>

# %% [markdown]
# What is the frequency of this timeseries? ________Hz

# %% [markdown]
# ## <font color=red>L.2) Frequency and Amplitude of a timeseries</font>

# %% [markdown]
# Write down a function that would create an 8 Hz timeseries:
#
# f[x] = _________.
#
# Write down a function that would create a 10 Hz timeseries with a gain of 8:
#
# g[x] = _______.
#
# Write down a function that would create a 5 Hz timeseries with a gain of 1/2:
#
# h[x] = _______.

# %% [markdown]
# ## <font color=red>L.3) Period of a timeseries</font>

# %% [markdown]
# Place a dot at the first period and each multiple of the period.

# %% [markdown]
# ## <font color=red>L.4) Period of a timeseries</font>

# %% [markdown]
# On the graph below, draw a 3 Hz timeseries with a symbol showing the first complete period.

# %% [markdown]
# ## <font color=red>L.5) Period of a timeseries</font>

# %% [markdown]
# On the graph below, show where the timeseries is at a phase of:
#
# (A) 90 degrees.
# (B) π radians
# (C) 2π radians
# (D) 270 degrees

# %% [markdown]
# ## <font color=red>L.6) Converting degrees to radians and radians to degrees</font>

# %% [markdown]
# Calculate the following. Show your work (i.e., the formulas you used)
#
# (A) 60 degrees = ___ radians
#
# (B) 270 degrees = ___ radians
#
# (C) π/3 radians = ___ degrees
#
# (D) 3π/4 radians = ___ degrees

# %% [markdown]
# ## <font color=red>L.7) Adding Time Series</font>

# %% [markdown]
# On the graph below, provide a rough sketch of the following timeseries: Sin[2 x] + Sin[2 x]. If needed,
# change the values on the y-axis.

# %% [markdown]
# ## <font color=red>L.8) Identities</font>

# %% [markdown]
# Write out the expansion of Sin[x] in powers of x.

# %% [markdown]
# ## <font color=red>L.9) Identities</font>

# %% [markdown]
# Describe in English why you'd prefer to use more terms in plotting the polynomial expansions of high
# than low frequencies.

# %% [markdown]
# ## <font color=red>L.10) Identities</font>

# %% [markdown]
# Write out the Euler Identities for $e^{i x}$ and $e^{-i x}$.

# %% [markdown]
# ## <font color=red>L.11) Identities</font>

# %% [markdown]
# **Extra credit and optional!**
#
# Use the Euler identities to derive an equation in terms of Cos[x]:

# %% [markdown]
# ## <font color=red>L.12) Identities</font>

# %% [markdown]
# **Extra credit and optional!**
#
# Use the formula you derived above to write out the formula for a 138 Hz cosine wave using Euler identities.

# %% [markdown]
# ## <font color=red>L.13) Identities</font>

# %% [markdown]
# **Extra credit and optional!**
#
# Write out the formula for a 55 Hz sine wave using Euler identities.

# %% [markdown]
# ## <font color=red>L.14) Identities</font>

# %% [markdown]
# We learned in the Tutorial section that we can plot a sine timeseries using the function f[x] = sin[x],
# using the polynomial expansion of sin[x], and using the complex exponential formula $(e^{I x}-e^{-I x})/(2 I)$. Which
# method do you prefer? Why?

# %% [markdown]
# ## <font color=red>L.15) Identities</font>

# %% [markdown]
# **Extra credit and optional!**
#
# Use the Euler identities to compute the number $e^{i pi / 2}$.

# %% [markdown]
# ## <font color=red>L.16) Identities</font>

# %% [markdown]
# Do you think that f(x + 2π) = f(x) for all x?

# %% [markdown]
# ## <font color=red>L.17) Spatial Data</font>

# %% [markdown]
# What is the 2D spatial frequencies of this image? ______cycles per meter and ______ cycles per meter

# %% [markdown]
# ## <font color=red>L.18) Show what you know</font>

# %% [markdown]
# Here is a function: f[t_] = a × Sin[2π t f + c], where t = time.
#
# Describe in words what effect the variables 'a', 'f', and 'c' have on the sine wave.
